# %%
# %load_ext autoreload
# %autoreload
import soundscapy.ssid.database as isd

# %%
ssid = isd.load_isd_dataset(version='latest', use_RecordID_as_index=False)
ssid.head()
# Out:
#    LocationID    SessionID GroupID  RecordID Language  Lockdown  \
# 0  CamdenTown  CamdenTown1   CT101     525.0  English         0
# 1  CamdenTown  CamdenTown1   CT101     561.0  English         0
# 2  CamdenTown  CamdenTown1   CT101     526.0  English         0
# 3  CamdenTown  CamdenTown1   CT102     560.0  English         0
# 4  CamdenTown  CamdenTown1   CT103     527.0  English         0
#
#            start_time            end_time   latitude  longitude  ...  \
# 0 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624  ...
# 1 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624  ...
# 2 2019-05-02 11:41:00 2019-05-02 11:44:00  51.539124  -0.142624  ...
# 3 2019-05-02 11:50:00 2019-05-02 11:53:00  51.539124  -0.142624  ...
# 4 2019-05-02 11:49:00 2019-05-02 11:54:00  51.539124  -0.142624  ...
#
#    FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 0              0.01700               0.358                    0.309
# ...

# %%
ssid._version
# Out:
# 'V0.2.2'

# %%
type(ssid)
# Out:
# soundscapy.ssid.database.SurveyFrame

# %%
ssid.filter_lockdown(is_lockdown=True)
# Out:
#         LocationID      SessionID GroupID  RecordID Language  Lockdown  \
# 106     CamdenTown    CamdenTown5   CT501       NaN      NaN         1
# 107     CamdenTown    CamdenTown5   CT502       NaN      NaN         1
# 108     CamdenTown    CamdenTown5   CT503       NaN      NaN         1
# 109     CamdenTown    CamdenTown5   CT504       NaN      NaN         1
# 110     CamdenTown    CamdenTown5   CT505       NaN      NaN         1
# ...            ...            ...     ...       ...      ...       ...
# 1904  TorringtonSq  TorringtonSq5   TS537       NaN      NaN         1
# 1905  TorringtonSq  TorringtonSq5   TS538       NaN      NaN         1
# 1906  TorringtonSq  TorringtonSq5   TS539       NaN      NaN         1
# 1907  TorringtonSq  TorringtonSq5   TS540       NaN      NaN         1
# 1908  TorringtonSq  TorringtonSq5   TS541       NaN      NaN         1
#
#      start_time end_time  latitude  longitude  ...  FS_Avg,arith(vacil)  \
# ...

# %%
ssid.return_paqs()
# Out:
#       RecordID GroupID      SessionID    LocationID  pleasant  vibrant  \
# 0        525.0   CT101    CamdenTown1    CamdenTown       2.0      3.0
# 1        561.0   CT101    CamdenTown1    CamdenTown       3.0      2.0
# 2        526.0   CT101    CamdenTown1    CamdenTown       4.0      3.0
# 3        560.0   CT102    CamdenTown1    CamdenTown       4.0      2.0
# 4        527.0   CT103    CamdenTown1    CamdenTown       3.0      5.0
# ...        ...     ...            ...           ...       ...      ...
# 1904       NaN   TS537  TorringtonSq5  TorringtonSq       NaN      NaN
# 1905       NaN   TS538  TorringtonSq5  TorringtonSq       NaN      NaN
# 1906       NaN   TS539  TorringtonSq5  TorringtonSq       NaN      NaN
# 1907       NaN   TS540  TorringtonSq5  TorringtonSq       NaN      NaN
# 1908       NaN   TS541  TorringtonSq5  TorringtonSq       NaN      NaN
#
#       eventful  chaotic  annoying  monotonous  uneventful  calm
# ...

# %%
from soundscapy.ssid import plotting
ssid.circumplex_scatter(s=20)
# Out:
# <AxesSubplot:title={'center':'Soundscape Scatter Plot'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %%
ssid.circumplex_density()
# Out:
# <AxesSubplot:title={'center':'Soundscape Density Plot'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %%
ssid.filter_location_ids(['TateModern', 'RegentsParkFields']).circumplex_jointplot(joint_kind='density', group='LocationID', palette='deep', legend=True)

# %%
plotting.paq_radar(ssid.filter_group_ids(['CT101']).convert_column_to_index('RecordID'))
# Out:
# <PolarAxesSubplot:>

# %%
# %autoreload
sf3 = isd.simulated_dataset(add_complex_paqs=True)
sf3.head()
# Out:
#    pleasant  vibrant  eventful  chaotic  annoying  monotonous  uneventful  \
# 0         3        3         2        3         4           3           3
# 1         4        2         3        2         2           3           2
# 2         1        3         1        3         3           1           4
# 3         4        1         3        3         3           3           4
# 4         4        1         2        4         3           2           3
#
#    calm  ISOPleasant  ISOEventful
# 0     2    -0.176777    -0.030330
# 1     3     0.207107    -0.042893
# 2     1    -0.207107    -0.017767
# 3     4     0.030330    -0.323223
# 4     2    -0.116117    -0.030330

# %% [markdown]
# `SurveyFrame` is just an extension of the pandas `DataFrame`, with some new methods specific to the SSID surveys! You should be able to use any of the standard dataframe methods on it.
#
# `SurveyFrame` automatically tags itself with the date you're working with it, stored in `_analysis_date`
